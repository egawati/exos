# %%
import pandas as pd
pd.set_option('display.precision', 3)
from ipynb.fs.full.graphs import plot_categorical_performance
from ipynb.fs.full.graphs import draw_multiple_plots_by_cases

# %%
case = 'Case1'
version = '_v3'
bfname = f'10K_{case}'
n_streams = 15
exp_num = 1
performance_folder = f'dbpca/pickles/performance/{case}{version}/windows/exp_{exp_num}'
basic_filename = f'{n_streams}_{bfname}_{exp_num}'
filename = f'aggregate_{basic_filename}.pkl'
df = pd.read_pickle(f'{performance_folder}/{filename}')
df
# Out:
#     window_size  precision  recall  f1_score  running_time
# 0           100      0.718   0.622     0.641        44.872
# 1           200      0.709   0.620     0.635        43.187
# 2           300      0.693   0.617     0.627        43.061
# 3           400      0.664   0.612     0.612        42.649
# 4           500      0.665   0.610     0.611        42.706
# 5           600      0.669   0.616     0.616        42.411
# 6           700      0.665   0.618     0.616        42.324
# 7           800      0.648   0.614     0.606        42.076
# 8           900      0.647   0.621     0.610        42.376
# 9          1000      0.640   0.624     0.607        42.428
# 10         1100      0.643   0.613     0.603        42.414
# 11         1200      0.638   0.615     0.601        42.664
# 12         1300      0.637   0.616     0.601        42.542
# 13         1400      0.640   0.629     0.608        42.789
# 14         1500      0.630   0.618     0.600        42.468

# %%
case = 'Case1'
version = '_v3'
bfname = f'10K_{case}'
n_streams = 15
exp_num = 30
performance_folder = f'dbpca/pickles/performance/{case}{version}/'
basic_filename = f'{n_streams}_{bfname}_{exp_num}'
filename = f'aggregate_{basic_filename}.pkl'
df = pd.read_pickle(f'{performance_folder}/{filename}')
df
# Out:
#     experiment  precision  recall  f1_score  running_time
# 0            1      0.645   0.626     0.608        42.199
# 1            2      0.747   0.646     0.671        42.356
# 2            3      0.722   0.644     0.657        43.137
# 3            4      0.722   0.645     0.662        42.624
# 4            5      0.647   0.624     0.612        42.466
# 5            6      0.699   0.645     0.651        42.530
# 6            7      0.748   0.638     0.666        42.987
# 7            8      0.717   0.633     0.648        41.842
# 8            9      0.743   0.657     0.675        42.419
# 9           10      0.737   0.647     0.667        42.816
# 10          11      0.716   0.640     0.649        42.538
# 11          12      0.696   0.624     0.636        42.664
# 12          13      0.690   0.635     0.639        42.687
# 13          14      0.717   0.655     0.659        42.759
# 14          15      0.716   0.636     0.652        42.317
# ...

# %%
case = 'Case4'
version = '_v3'
bfname = f'10K_{case}'
n_streams = 15
exp_num = 30
performance_folder = f'dbpca/pickles/performance/{case}{version}/'
basic_filename = f'{n_streams}_{bfname}_{exp_num}'
filename = f'aggregate_{basic_filename}.pkl'
df = pd.read_pickle(f'{performance_folder}/{filename}')
df
# Out:
#     experiment  precision  recall  f1_score  running_time
# 0            1      0.639   0.617     0.601        42.001
# 1            2      0.724   0.650     0.665        42.249
# 2            3      0.700   0.639     0.645        42.627
# 3            4      0.740   0.645     0.671        42.591
# 4            5      0.651   0.621     0.608        42.638
# 5            6      0.706   0.641     0.648        42.648
# 6            7      0.735   0.646     0.664        42.592
# 7            8      0.707   0.642     0.649        42.237
# 8            9      0.755   0.645     0.673        43.178
# 9           10      0.730   0.645     0.662        42.772
# 10          11      0.697   0.635     0.638        42.374
# 11          12      0.700   0.643     0.648        42.254
# 12          13      0.665   0.641     0.629        42.676
# 13          14      0.689   0.638     0.637        43.245
# 14          15      0.689   0.638     0.641        43.520
# ...
