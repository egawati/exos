# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
sys.path.insert(1, module_path)

from metrics import get_performance_df_v2

# %% [markdown]
# ## Case 1

# %%
case = 'Case1'
bfname = f'100K_{case}'
nstreams = 15
df = get_performance_df_v2(n_streams=nstreams, 
                          bfname = bfname, 
                          gt_folder = '/home/epanjei/Codes/OutlierGen/exos/cases',
                          rel_path =  f'pickles/cases/{case}',
                          performance_folder = 'pickles/performance/cases',
                          n_experiments=10,
                          window_size=1000,
                          non_data_attr=2,
                          vcase=case)
df
# Out:
# Generating
# Comparing experiments stored in /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/cases/Case1/15 with ground truth stores in /home/epanjei/Codes/OutlierGen/exos/cases/Case1
# Perfomance is stored is /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/performance/cases/Case1/15
#    experiment  precision    recall  f1_score  running_time
# 0           1   0.846116  0.676088  0.731650     78.737364
# 1           2   0.829281  0.667468  0.720600     77.595814
# 2           3   0.860421  0.688744  0.744177     78.326762
# 3           4   0.855082  0.691158  0.743208     76.774379
# 4           5   0.844648  0.679288  0.732567     76.555051
# 5           6   0.857770  0.682577  0.739618     77.438153
# 6           7   0.845507  0.673080  0.729825     77.705970
# 7           8   0.859593  0.684216  0.741819     77.830575
# 8           9   0.842820  0.682210  0.734064     77.788199
# 9          10   0.830758  0.680979  0.726594     77.724599

# %% [markdown]
# ## Case 2

# %%
case = 'Case2'
bfname = f'100K_{case}'
nstreams = 15
df = get_performance_df_v2(n_streams=nstreams, 
                          bfname = bfname, 
                          gt_folder = '/home/epanjei/Codes/OutlierGen/exos/cases',
                          rel_path =  f'pickles/cases/{case}',
                          performance_folder = 'pickles/performance/cases',
                          n_experiments=10,
                          window_size=1000,
                          non_data_attr=2,
                          vcase=case)
df
# Out:
# Generating
# Comparing experiments stored in /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/cases/Case2/15 with ground truth stores in /home/epanjei/Codes/OutlierGen/exos/cases/Case2
# Perfomance is stored is /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/performance/cases/Case2/15
#    experiment  precision    recall  f1_score  running_time
# 0           1   0.839170  0.677657  0.728141     76.717172
# 1           2   0.842053  0.668397  0.724543     77.839135
# 2           3   0.835501  0.672356  0.723861     77.078046
# 3           4   0.839119  0.669220  0.724288     77.452107
# 4           5   0.832830  0.662371  0.717417     77.184772
# 5           6   0.817017  0.666625  0.711668     77.319996
# 6           7   0.849623  0.683913  0.735016     76.995719
# 7           8   0.813653  0.660094  0.707496     77.739632
# 8           9   0.860707  0.679305  0.738878     77.402046
# 9          10   0.841596  0.672186  0.726597     78.827140

# %% [markdown]
# ## Case 3

# %%
case = 'Case3'
bfname = f'100K_{case}'
nstreams = 15
df = get_performance_df_v2(n_streams=nstreams, 
                          bfname = bfname, 
                          gt_folder = '/home/epanjei/Codes/OutlierGen/exos/cases',
                          rel_path =  f'pickles/cases/{case}',
                          performance_folder = 'pickles/performance/cases',
                          n_experiments=10,
                          window_size=1000,
                          non_data_attr=2,
                          vcase=case)
df
# Out:
# Generating
# Comparing experiments stored in /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/cases/Case3/15 with ground truth stores in /home/epanjei/Codes/OutlierGen/exos/cases/Case3
# Perfomance is stored is /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/performance/cases/Case3/15
#    experiment  precision    recall  f1_score  running_time
# 0           1   0.865803  0.692544  0.748379     77.609009
# 1           2   0.856922  0.685755  0.740968     75.987252
# 2           3   0.863646  0.687997  0.744940     77.080110
# 3           4   0.863322  0.681496  0.741996     77.027873
# 4           5   0.850269  0.673318  0.731809     77.768369
# 5           6   0.853849  0.685721  0.740089     78.201806
# 6           7   0.844008  0.679835  0.731308     77.485253
# 7           8   0.842382  0.670181  0.725022     77.728799
# 8           9   0.857401  0.679341  0.737885     77.040289
# 9          10   0.864529  0.686424  0.745736     76.841384

# %% [markdown]
# ## Case 4

# %%
case = 'Case4'
bfname = f'100K_{case}'
nstreams = 15
df = get_performance_df_v2(n_streams=nstreams, 
                          bfname = bfname, 
                          gt_folder = '/home/epanjei/Codes/OutlierGen/exos/cases',
                          rel_path =  f'pickles/cases/{case}',
                          performance_folder = 'pickles/performance/cases',
                          n_experiments=10,
                          window_size=1000,
                          non_data_attr=2,
                          vcase=case)
df
# Out:
# Generating
# Comparing experiments stored in /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/cases/Case4/15 with ground truth stores in /home/epanjei/Codes/OutlierGen/exos/cases/Case4
# Perfomance is stored is /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/performance/cases/Case4/15
#    experiment  precision    recall  f1_score  running_time
# 0           1   0.830319  0.666420  0.719243     75.882955
# 1           2   0.828695  0.659663  0.714861     77.291436
# 2           3   0.846640  0.677629  0.731388     77.985146
# 3           4   0.850210  0.676165  0.733399     75.978810
# 4           5   0.859066  0.685092  0.741110     77.445869
# 5           6   0.852916  0.691212  0.741433     78.010598
# 6           7   0.860266  0.689278  0.743576     77.773426
# 7           8   0.858956  0.684384  0.740887     76.601901
# 8           9   0.838771  0.672936  0.726619     77.353482
# 9          10   0.843986  0.677265  0.729807     78.988797
