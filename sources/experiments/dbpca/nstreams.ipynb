# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
sys.path.insert(1, module_path)

from metrics import get_performance_df_v2

import pandas as pd
pd.set_option('display.precision', 2)

import pickle

# %% [markdown]
# # Accuracy and Running Time

# %%
df = get_performance_df_v2(n_streams=50,
                          bfname = '100K_Case1', 
                          gt_folder = '/home/epanjei/Codes/OutlierGen/exos/nstreams',
                          rel_path =  'pickles/nstreams',
                          performance_folder = 'pickles/performance/nstreams',
                          n_experiments=10,
                          window_size=1000,
                          non_data_attr=2)

df
# Out:
# Generating
# Comparing experiments stored in /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/nstreams/50 with ground truth stores in /home/epanjei/Codes/OutlierGen/exos/nstreams/50
# Perfomance is stored is /home/epanjei/Codes/EXOS/sources/experiments/dbpca/pickles/performance/nstreams/50
#    experiment  precision  recall  f1_score  running_time
# 0           1       0.86    0.69      0.75        280.53
# 1           2       0.85    0.69      0.73        281.31
# 2           3       0.85    0.69      0.73        281.01
# 3           4       0.84    0.69      0.73        279.31
# 4           5       0.85    0.69      0.74        279.94
# 5           6       0.87    0.70      0.75        279.11
# 6           7       0.84    0.69      0.73        280.51
# 7           8       0.84    0.69      0.73        279.69
# 8           9       0.85    0.69      0.74        281.51
# 9          10       0.86    0.69      0.74        278.75

# %%
def recap_performance_info(rel_path =  'pickles/performance/nstreams', 
                           n_streams=(5,10,15,20,25,30,35,40,45,50),
                           bname = '100K_Case1'):
    cwd = os.getcwd()
    avg_precision = list()
    avg_recall = list()
    avg_f1_score = list()
    avg_running_time = list()
    streams = list()
    for nstreams in n_streams:
        file_path = f'{rel_path}/{nstreams}/aggregate_{nstreams}_{bname}.pkl'
        path = os.path.join(cwd, file_path)
        df = pd.read_pickle(path)
        avg_precision.append(df['precision'].mean())
        avg_recall.append(df['recall'].mean())
        avg_f1_score.append(df['f1_score'].mean())
        avg_running_time.append(df['running_time'].mean())
        streams.append(nstreams)
    performance = {'nstreams' : streams, 
                   'avg_precision' : avg_precision,
                   'avg_recall' : avg_recall,
                   'avg_f1_score' : avg_f1_score,
                   'avg_running_time' : avg_running_time}
    df = pd.DataFrame(performance)
    df.to_pickle(f'{rel_path}/avg_performance_{bname}.pkl')
    return df
recap_performance_info(rel_path  =  'pickles/performance/nstreams', 
                       n_streams = (5,10,15,20,25,30,35,40,45,50),
                       bname = '100K_Case1')
# Out:
#    nstreams  avg_precision  avg_recall  avg_f1_score  avg_running_time
# 0         5           0.77        0.67          0.69             36.02
# 1        10           0.80        0.67          0.70             57.04
# 2        15           0.82        0.69          0.72             77.15
# 3        20           0.83        0.69          0.73            108.40
# 4        25           0.83        0.68          0.72            132.50
# 5        30           0.84        0.69          0.73            161.92
# 6        35           0.84        0.69          0.73            187.04
# 7        40           0.84        0.68          0.73            218.55
# 8        45           0.84        0.69          0.73            249.03
# 9        50           0.85        0.69          0.74            280.17
