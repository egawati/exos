# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def create_heatmap(df_corr):
    fig, ax = plt.subplots(figsize=(10, 8))
    # mask
    mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
    # adjust mask and df
    mask = mask[1:, :-1]
    corr = df_corr.iloc[1:,:-1].copy()
    # plot heatmap
    sns.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap='Blues',
               vmin=-1, vmax=1, cbar_kws={"shrink": .8})
    # yticks
    plt.yticks(rotation=0)
    plt.show()

# %%
folder = 'Nchanges'
nstreams = 4
bfname = 'cd_nchanges'
wsize = 1000
total_windows = 11

# %% [markdown]
# ## Data in Stream 1

# %% [markdown]
# Let's examine data where 10 concept drift happen.

# %%
filename = f'0_{bfname}_10.pkl'
df = pd.read_pickle(f'{folder}/{filename}')
df = df.drop(['label', 'outlying_attributes'], axis=1)

# %%
means = list()
sigmas = list()

# %%
start = 0
end = wsize
wdata = {}
data = None
for i in range(total_windows):
    new_df = df.iloc[start:end]
    new_df['window'] = i
    wdata[i] = new_df
    if data is None:
        data = new_df
    else:
        data = data.append(new_df, ignore_index=True)
    start = end
    end += wsize

# %%
data_0 = wdata[0]
data_0 = data_0.append(wdata[1], ignore_index=True)
data_0 = data_0.append(wdata[2], ignore_index=True)
data_0 = data_0.append(wdata[3], ignore_index=True)
data_0 = data_0.append(wdata[4], ignore_index=True)
data_0 = data_0.append(wdata[5], ignore_index=True)
data_0 = data_0.append(wdata[6], ignore_index=True)
data_0 = data_0.append(wdata[7], ignore_index=True)
data_0 = data_0.append(wdata[8], ignore_index=True)
data_0 = data_0.append(wdata[9], ignore_index=True)
data_0 = data_0.append(wdata[10], ignore_index=True)
sns.set_palette("dark")
sns.displot(data_0, x="V1", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V2", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V3", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V4", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V5", hue="window", kind="kde",  palette='colorblind')
plt.xlim(-10,200)
# Out:
# (-10.0, 200.0)

# %%
sns.displot(data_0, x="V6", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V7", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V8", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V9", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
sns.displot(data_0, x="V10", hue="window", kind="kde",  palette='colorblind')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)
